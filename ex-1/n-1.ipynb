# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import rotate_axes

# %%
accidents = pd.read_csv('data/accidents.csv')
accidents
# Out:
#   Miles from Home  % of Accidents
# 0     less than 1              23
# 1          1 to 5              29
# 2         6 to 10              17
# 3        11 to 15               8
# 4        16 to 20               6
# 5         over 20              17

# %%
accidents.shape
# Out:
# (6, 2)

# %%
accidents.describe()
# Out:
#        % of Accidents
# count        6.000000
# mean        16.666667
# std          8.733079
# min          6.000000
# 25%         10.250000
# 50%         17.000000
# 75%         21.500000
# max         29.000000

# %%
plt.bar(accidents['Miles from Home'], accidents['% of Accidents'])
plt.xlabel('accidents group')
plt.xticks(rotation=70)
plt.ylabel('counts')
plt.title('Accidents by groups')
# Out:
# Text(0.5, 1.0, 'Accidents by groups')
